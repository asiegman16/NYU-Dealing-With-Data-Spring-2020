# %% [markdown]
# # All material ©2019, Alex Siegman

# %% [markdown]
# ---

# %% [markdown]
# ### Below is the code used to generate the mock dataset for Stern Technologies

# %%
import pandas as pd
import random
import uuid # https://docs.python.org/3/library/uuid.html

# %%
# user ID creation

id_list = []

for i in range(0,50000):
    id = uuid.uuid4() # generate a random UUID
    id_list.append(str(id))

# %%
id_list[:5] # see the first five UUID's generated by the loop above
# Out:
# ['081217b4-1cf5-4657-8287-6db1b75462e4',
#  'd0b45a01-b73d-4f8e-bfa8-c53ea75397f1',
#  '1dc2e636-e19b-4d42-b228-df09cd009acb',
#  '5d09d6d4-023e-4fa1-9559-89526679e885',
#  'b69e54e3-fc89-4c0f-8bdb-280409db173e']

# %%
# company size creation 

company_size_list = []

for i in range(0,50000):
    size = random.choice(['startup','small','medium','large']) # choose a random size from the 'sizes' list
    company_size_list.append(size)

# %%
company_size_list[:5] # see the first five company sizes generated by the loop above
# Out:
# ['large', 'large', 'large', 'large', 'medium']

# %%
# age

age_list = []

for i in range(0,50000):
    age = random.randint(18,99) # choose a random age between 18 and 99
    age_list.append(int(age))

# %%
age_list[:5] # see the first five ages generated by the loop above
# Out:
# [92, 56, 20, 55, 25]

# %%
# sex

sex_list = []

sexes = ['M','F','N']

for i in range(0,50000):
    sex = random.choice(sexes) # choose a M, F, or N (for non-binary)
    sex_list.append(str(sex))

# %%
sex_list[:5] # see the first five sexes generated by the loop above
# Out:
# ['M', 'M', 'F', 'F', 'N']

# %%
# clicked on ad

clicked_on_ad_list = []

actions = ['Yes','No']

for i in range(0,50000):
    choice = random.choice(actions) # choose either 'Yes' or 'No'
    clicked_on_ad_list.append(str(choice))

# %%
clicked_on_ad_list[:5] # see the first five user actions generated by the loop above
# Out:
# ['Yes', 'Yes', 'No', 'Yes', 'No']

# %%
# ad type

ad_type_list = []

ad_types = ['Tech','Luxury','Culinary','Fashion','Travel','Political','Business','Real Estate']

for i in range(0,50000):
    ad_type = random.choice(ad_types) # choose one of the ad types
    ad_type_list.append(ad_type)

# %%
ad_type_list[:5] # see the first five ad types generated by the loop above
# Out:
# ['Business', 'Culinary', 'Business', 'Political', 'Tech']

# %%
# location

location_list = []

locations = ['US','NorthEast','SouthEast','MidWest','SouthWest','NorthWest','Canada','Mexico','SouthAmerica']

for i in range(0,50000):
    location = random.choice(locations) # choose one of the locations
    location_list.append(str(location))

# %%
location_list[:5] # see the first five locations generated by the loop above
# Out:
# ['MidWest', 'SouthWest', 'SouthEast', 'NorthWest', 'US']

# %%
# timestamp

from datetime import *

timestamp_list = []

def gen_datetime(min_year=2000, max_year=datetime.now().year):
    start = datetime(min_year, 1, 1, 00, 00, 00)
    years = max_year - min_year + 1
    end = start + timedelta(days = 365 * years)
    return start + (end - start) * random.random()

for i in range(0,50000): 
    timestamp = gen_datetime()
    timestamp_list.append(timestamp)

timestamp_list[:5] # view the first five random timestamps generated in the loop above
# Out:
# [datetime.datetime(2018, 8, 26, 6, 0, 27, 124290),
#  datetime.datetime(2011, 6, 1, 18, 54, 34, 815634),
#  datetime.datetime(2013, 7, 16, 0, 24, 47, 888180),
#  datetime.datetime(2010, 6, 25, 12, 13, 51, 369878),
#  datetime.datetime(2010, 9, 22, 7, 53, 12, 454909)]

# %%
user_data = pd.DataFrame({'id':id_list,'company_size':company_size_list,'age':age_list,'sex':sex_list,'clicked_on_ad':clicked_on_ad_list,'ad_type':ad_type_list,'location':location_list,'timestamp':timestamp_list})

# %%
user_data
# Out:
#                                          id company_size  age sex  \
# 0      081217b4-1cf5-4657-8287-6db1b75462e4        large   92   M
# 1      d0b45a01-b73d-4f8e-bfa8-c53ea75397f1        large   56   M
# 2      1dc2e636-e19b-4d42-b228-df09cd009acb        large   20   F
# 3      5d09d6d4-023e-4fa1-9559-89526679e885        large   55   F
# 4      b69e54e3-fc89-4c0f-8bdb-280409db173e       medium   25   N
# 5      26753d01-eaf3-4906-a0e8-ec3364e336ab        large   87   N
# 6      8b449b66-55fb-411b-a27d-81f88d12d6e2      startup   39   N
# 7      ec5a6353-f816-4737-8fed-a8a620fe70c3       medium   39   N
# 8      3d732520-cbb7-4e90-8d17-5dcd12ae3ea2        small   62   M
# 9      eedba0f5-0e4b-49b2-8409-62b24761a05a        large   76   F
# 10     287cf905-00d3-4347-a5f5-e82876f7e309       medium   58   F
# 11     3f3bbed7-5fe9-411d-8f9c-1df9729b2c8a      startup   38   F
# 12     91f3fc7f-42ec-4d5a-85c9-4e8292fef5ad        large   71   N
# 13     e013c5de-837c-450e-826b-94379acd9a08      startup   53   F
# 14     c0f7004a-e8ca-4bbb-8144-96f63ab6a55c        small   25   F
# 15     fc9f29d9-6042-44c6-b996-04caefa6e2cc        large   39   M
# 16     346471ed-a4e7-46b3-9418-7dff84b50132        large   95   F
# 17     b7a2c7bf-b539-465b-852c-d30bbd3e2a55      startup   42   N
# 18     cf8b2003-683e-42e9-8ade-58885d10f6c5        large   37   M
# 19     433540d6-2c81-4afb-a2bf-4ad91819b004        small   38   N
# 20     0ee537f8-26b1-43c7-bea6-7388d4ec4feb        large   30   F
# 21     091298d5-975e-4137-8500-b859dff1f594       medium   56   M
# 22     624dac66-9096-408b-99b1-9b943308a5a7        large   56   M
# 23     12a23151-19f6-4e5b-ab9b-dddcd70e6847       medium   80   F
# 24     65d697a9-daee-43b7-a6a8-0316a9f5110f      startup   43   N
# 25     0d70d5ec-ba16-46ec-9872-f66927a5c6e9      startup   42   N
# 26     724c5b89-637a-49ac-83d0-4bf8f78ebac8        large   85   F
# 27     06ee8cb1-0297-4e32-aeee-36432d81cafd        small   71   M
# 28     2d81a06c-f707-4139-93e5-c093ff9949d5        large   27   F
# 29     a5d95b35-e9a5-4c21-8c2e-ec2a99e72a41        small   82   M
# ...                                     ...          ...  ...  ..
# 49970  e8ed514f-4038-416e-80a2-57cdba8fbd17        small   31   N
# 49971  7f5e75fc-7251-403b-9b27-d0c086392578      startup   87   N
# 49972  bee77a07-8a4a-46ff-ba6d-36af11f66f29        large   26   M
# 49973  d5d76336-c521-4939-999c-7d7cd9de6faf        small   60   M
# 49974  85ef03d1-7e59-42bb-ba7f-68f1a684583b        small   66   M
# 49975  cdd54ce9-4ca3-49db-a57e-46dad22a7b66       medium   40   N
# 49976  341fdcd7-4c17-4be2-8b6b-752d263f96ee      startup   70   N
# 49977  bc6d61d2-391b-4904-9118-a0fbf3ceb183        large   66   F
# 49978  ca4e5eb7-e812-49ee-acc6-296368c967c7      startup   95   F
# 49979  93eb99d0-e388-4058-8ef0-4104c20055c6        small   87   N
# 49980  2e1b1175-8d3b-42a0-92aa-3dee67b17518       medium   81   M
# 49981  73a3bbac-ee5f-48b1-b520-e1af86cb486c      startup   85   F
# 49982  d6c2d2c6-a659-4cca-906c-e8bd1a2e760d        small   92   M
# 49983  06363885-e80b-42fc-997b-2fcec9ac0ee6        small   97   F
# 49984  b527e67c-def9-4761-a962-062348bdde35        small   54   F
# 49985  29e48b49-1719-4cc3-9429-492c13fc2b86      startup   69   F
# 49986  8a3cf957-0886-4f93-8355-e6fa3c8cacee        large   46   F
# 49987  b631e6eb-90ff-459f-8a9c-ab8090b1fcdc        small   54   F
# 49988  07667c41-515a-48af-ad4e-ef4be337a26d        small   62   F
# 49989  29400ca0-8c39-48ff-9ef8-de01d0c5f7ea       medium   68   N
# 49990  cc41c3b3-b28b-4716-87a9-61f7b4d7e90d       medium   74   M
# 49991  bc2a2fd0-49d7-40c2-ae1d-38e6856ff6d6        small   97   F
# 49992  02fd58df-7db6-42d3-8e4d-6d6319c580f6        large   98   M
# 49993  5cfbd907-dd55-46fe-aafc-99a8b78ce7b2        large   56   F
# 49994  0339fe42-9b42-47e6-991a-8d51fcb2f7da        large   90   F
# 49995  fff66dc6-51cd-411e-8cea-95ce9545824a        large   58   M
# 49996  33bcab3a-ce18-4105-8dff-e69dae652d91        small   68   F
# 49997  360e2ac2-33b9-48d5-a7a6-6cabb4536897      startup   84   F
# 49998  fab46f7a-eb83-47e2-b902-a62e52c3c0f0       medium   39   N
# 49999  1fcd6f7a-9538-4699-8f3b-5add91f5fde9        small   55   N
#
#       clicked_on_ad      ad_type      location                  timestamp
# 0               Yes     Business       MidWest 2018-08-26 06:00:27.124290
# 1               Yes     Culinary     SouthWest 2011-06-01 18:54:34.815634
# 2                No     Business     SouthEast 2013-07-16 00:24:47.888180
# 3               Yes    Political     NorthWest 2010-06-25 12:13:51.369878
# 4                No         Tech            US 2010-09-22 07:53:12.454909
# 5               Yes    Political        Canada 2018-08-07 01:14:12.732566
# 6                No  Real Estate     SouthEast 2003-05-31 07:24:51.873042
# 7                No     Business  SouthAmerica 2015-08-26 08:07:55.115573
# 8               Yes         Tech  SouthAmerica 2017-06-15 10:03:34.420593
# 9                No       Luxury     SouthEast 2008-10-10 16:28:52.002102
# 10               No     Culinary  SouthAmerica 2002-09-15 07:49:05.836594
# 11               No     Business        Canada 2000-04-24 05:17:52.712711
# 12               No       Travel            US 2005-11-22 03:13:11.646444
# 13              Yes       Luxury            US 2009-02-17 07:44:36.928736
# 14              Yes    Political        Canada 2016-10-12 13:48:46.967447
# 15               No  Real Estate     NorthWest 2010-11-06 04:46:03.849307
# 16              Yes     Culinary     NorthEast 2006-09-30 02:14:29.869183
# 17              Yes      Fashion        Canada 2019-02-08 16:37:45.591904
# 18              Yes  Real Estate     NorthEast 2012-08-03 04:14:23.392726
# 19               No     Business  SouthAmerica 2016-04-17 07:47:11.368449
# 20               No      Fashion            US 2008-12-27 08:51:16.134757
# 21               No         Tech        Canada 2013-02-06 20:53:02.571888
# 22              Yes       Luxury  SouthAmerica 2015-06-09 21:46:58.177888
# 23               No     Business     NorthWest 2002-05-03 05:40:09.073365
# 24              Yes       Luxury       MidWest 2017-01-22 22:27:32.588528
# 25               No      Fashion     SouthEast 2010-10-05 15:01:40.775792
# 26               No       Travel            US 2019-02-10 06:10:07.692212
# 27               No  Real Estate     NorthEast 2011-08-21 04:06:00.501501
# 28               No    Political        Canada 2000-07-28 13:38:10.515988
# 29              Yes     Business     SouthWest 2006-04-27 16:50:35.989215
# ...             ...          ...           ...                        ...
# 49970            No  Real Estate       MidWest 2014-10-08 14:52:04.905087
# 49971            No      Fashion        Canada 2001-05-15 15:17:25.991333
# 49972            No  Real Estate        Mexico 2010-04-12 15:21:21.245041
# 49973           Yes     Business       MidWest 2009-04-01 18:33:04.451073
# 49974           Yes     Culinary       MidWest 2008-05-02 19:14:23.126378
# 49975           Yes     Business        Canada 2004-09-06 19:20:59.138719
# 49976           Yes     Culinary     NorthEast 2003-09-16 10:03:57.672818
# 49977           Yes      Fashion     SouthWest 2018-07-15 13:37:25.242294
# 49978           Yes  Real Estate     NorthEast 2007-03-26 19:35:33.029447
# 49979           Yes       Luxury        Canada 2004-11-15 18:19:48.637642
# 49980           Yes       Luxury  SouthAmerica 2019-02-04 03:14:20.645672
# 49981            No     Culinary        Canada 2000-07-10 01:59:33.753225
# 49982            No         Tech     SouthEast 2007-10-23 14:22:08.910995
# 49983           Yes       Luxury        Canada 2018-02-27 11:02:55.640040
# 49984           Yes    Political  SouthAmerica 2016-05-18 16:24:39.492705
# 49985            No     Business        Canada 2004-10-25 01:50:34.348428
# 49986           Yes     Business     SouthEast 2008-05-10 07:45:29.739686
# 49987            No       Travel     NorthEast 2018-03-31 02:49:54.681843
# 49988            No     Business     SouthWest 2004-06-26 00:41:03.142761
# 49989           Yes      Fashion     NorthWest 2016-07-05 20:50:41.126145
# 49990           Yes         Tech  SouthAmerica 2004-12-28 20:22:19.315795
# 49991            No         Tech  SouthAmerica 2019-06-25 02:44:36.845612
# 49992           Yes       Travel        Canada 2011-10-29 05:17:46.924480
# 49993            No      Fashion     SouthEast 2003-12-16 16:50:47.439505
# 49994            No     Business            US 2011-08-15 00:25:54.927637
# 49995           Yes       Travel     SouthWest 2014-10-25 03:59:34.571166
# 49996            No    Political        Canada 2018-08-15 18:52:06.433705
# 49997           Yes     Culinary        Mexico 2014-02-24 09:55:27.174267
# 49998           Yes      Fashion     SouthWest 2017-02-17 01:54:56.617956
# 49999            No  Real Estate     NorthEast 2018-01-17 03:06:26.410754
#
# [50000 rows x 8 columns]

# %%
user_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 8 columns):
# id               50000 non-null object
# company_size     50000 non-null object
# age              50000 non-null int64
# sex              50000 non-null object
# clicked_on_ad    50000 non-null object
# ad_type          50000 non-null object
# location         50000 non-null object
# timestamp        50000 non-null datetime64[ns]
# dtypes: datetime64[ns](1), int64(1), object(6)
# memory usage: 3.1+ MB

# %%
user_data.to_csv('./SternTech_UserData.csv')
