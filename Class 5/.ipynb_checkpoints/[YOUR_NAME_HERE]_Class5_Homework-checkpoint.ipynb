# %% [markdown]
# # To submit this assignment, please solve the following problem and follow the instructions below.

# %% [markdown]
# ---

# %% [markdown]
# OVERVIEW: Your task in this homework assingment is to continue building out our Class Project's database using the knowledge from class and files provided on NYU Classes.
#
# Problem 1 (4 points):
#
# > Use SQLiteStudio to create the nyc_films_permits table within the nyc_media_rep_db database on your laptop which we created together in class on Mar 14. Submit the CREATE TABLE statement generated by SQLiteStudio as a file attachment to this NYU Classes assignment. (*This can be a png, jpg, pdf, screen-shot - whatever you would like*)
#
# Problem 2 (4 points):
#
# > Populate the new nyc_film_permits table by using SQLiteStudio to import the data found in the nyc_film_permits.tsv posted to NYU Classes. Run one SQL query using what you learned in class to display data from this new table. Your query must be a SELECT ... FROM statement with at least one other SQL command (e.g. DISTINCT, WHERE, LIMIT, etc). Submit your SQL query and resulting data view (screenshot or data file are both acceptable) as a file attachment to this NYU Classes assignment.(*This can be a png, jpg, pdf, screen-shot - whatever you would like*)
#
# Problem 3 (2 points):
#
# > Describe the relationships between all the tables (nyc_film_permits, irs_agi_map, and irs_nyc_tax_returns) in the updated nyc_media_rep_db database, either in words or as a diagram created by updating the ERD found on NYU Classes. Submit your chosen form of the described relationships to this assignment in NYU Classes.
